# %% [markdown]
# ### Embedding Layer

# %%
from keras.datasets import imdb 
from keras import Sequential 
from keras.layers import Dense,SimpleRNN,Embedding,Flatten
# Out:
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
docs = [
    "go India",
    "india india",
    "hip hip hurray",
    "jeetega bhai jeetega india jeetega",
    'bharat mata ki jai',
    'kohli kohli',
    'sachin sachin',
    'dhoni dhoni',
    'modi ji ki jai',
    'inquilab' 
]

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
# tokenizer.word_index

# %%
sequences=tokenizer.texts_to_sequences(docs)

# %%
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16]]

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16,  0,  0,  0,  0]])

# %% [markdown]
# Embedding(vocabulary-unique words, represent kaise krna hai yaha vo number daalo kindoff hyperparameter jaisa , Input_length yahape kitne words hai vo batado )

# %%
model = Sequential() 
model.add(Embedding(17,output_dim=2,input_length=5))
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 2)              34
#
# =================================================================
# Total params: 34 (136.00 Byte)
# Trainable params: 34 (136.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 [==============================] - 0s 366ms/step
# [[[-0.04646134  0.03316012]
#   [ 0.04949545 -0.00546646]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]
#
#  [[ 0.04949545 -0.00546646]
#   [ 0.04949545 -0.00546646]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]
#
#  [[-0.02818537 -0.01778654]
#   [-0.02818537 -0.01778654]
#   [-0.01411837 -0.03761717]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]
#
#  [[ 0.00068523  0.00453341]
#   [ 0.02352435 -0.03089461]
#   [ 0.00068523  0.00453341]
#   [ 0.04949545 -0.00546646]
#   [ 0.00068523  0.00453341]]
#
#  [[-0.04323006  0.02241416]
#   [-0.01395608  0.03690802]
#   [-0.00391241  0.04759263]
#   [ 0.03719253 -0.01517768]
#   [ 0.03541036  0.04738447]]
#
#  [[-0.02313883  0.02667568]
#   [-0.02313883  0.02667568]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]
#
#  [[-0.0076968  -0.0492375 ]
#   [-0.0076968  -0.0492375 ]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]
#
#  [[-0.04261171 -0.04845034]
#   [-0.04261171 -0.04845034]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]
#
#  [[-0.02713439  0.03759238]
#   [-0.01068113 -0.02894274]
#   [-0.00391241  0.04759263]
#   [ 0.03719253 -0.01517768]
#   [ 0.03541036  0.04738447]]
#
#  [[ 0.02607829  0.0362324 ]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]
#   [ 0.03541036  0.04738447]]]
